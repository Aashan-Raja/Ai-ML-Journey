# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Creating a Data Frame.

# %%
data = {
    'Name' : ['John','Anna','Peter','Linda'],
    'Age'  : [28 ,34,29,42],
    'City' : ['New York' ,'Paris','Berlin','London'],
    'Salary' :[65000,70000,62000,85000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# Selection and indexing of columns.

# %%
df["Name"]
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: str

# %%
df[["Name","Age"]]
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# Creating new column

# %%
df["Desigination"] = ["Docter","Enginner","labour","Electircian"]
df
# Out:
#     Name  Age      City  Salary Desigination
# 0   John   28  New York   65000       Docter
# 1   Anna   34     Paris   70000     Enginner
# 2  Peter   29    Berlin   62000       labour
# 3  Linda   42    London   85000  Electircian

# %% [markdown]
# Removing columns.

# %%
df.drop("Desigination",axis=1 , inplace=True)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# Selecting Rows.

# %%
df.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df.iloc[1]
# Out:
# Name       Anna
# Age          34
# City      Paris
# Salary    70000
# Name: 1, dtype: object

# %% [markdown]
# Selecting Subsets of Rows and Columns

# %%
df.loc[[2,3]][['Name','Age']]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# Conditional Selection

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#I only want to see those peoples whose age is above 30
df[df["Age"] > 30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
#I only want people whose age is above 30 and their city must be paris
df[(df["Age"] > 30) & (df["City"] == "Paris")]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
